# %% [markdown]
# # Exercice 2
# Make this image
# ![image.png](attachment:image.png)

# %%
from vpython import *
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
sphere_1 = sphere(pos=vector(-1,0,0), radius=0.25, color= color.green)
sphere_2 = sphere(pos=vector(1,1,0), radius=0.25, color= color.blue)
sphere_3 = sphere(pos=vector(1,-1,0), radius=0.25, color= color.yellow)

# %%
arrow_1= arrow(pos=sphere_1.pos,axis=sphere_3.pos-sphere_1.pos,color=color.red)
arrow_2= arrow(pos=sphere_3.pos,axis=sphere_2.pos-sphere_3.pos,color=color.red)
arrow_3= arrow(pos=sphere_2.pos,axis=sphere_1.pos-sphere_2.pos,color=color.red)
